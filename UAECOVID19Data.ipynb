# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.plotting.register_matplotlib_converters()
# %matplotlib notebook

# %%
covidata = pd.read_csv(r"C:\Users\codem\Desktop\PROGRAMMINGCAMP.ORG\7 GOALS\PROJECTS\UAECOVID19Data.csv",index_col="Date",parse_dates=True)
dat = pd.DataFrame(covidata)

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 162 entries, 2020-01-29 to 2020-08-08
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Day               162 non-null    int64
#  1   Confirmed Cases   162 non-null    int64
#  2   Recovered         162 non-null    int64
#  3   Confirmed Deaths  162 non-null    int64
#  4   Tests             162 non-null    int64
#  5   Active Cases      162 non-null    int64
# dtypes: int64(6)
# memory usage: 8.9 KB

# %%
dat.describe()
# Out:
#               Day  Confirmed Cases    Recovered  Confirmed Deaths  \
# count  162.000000       162.000000   162.000000        162.000000
# mean    81.500000       384.567901   347.191358          2.197531
# std     46.909487       246.777917   319.321049          2.587211
# min      1.000000         0.000000     0.000000          0.000000
# 25%     41.250000       239.000000    52.750000          0.000000
# 50%     81.500000       389.000000   335.500000          1.000000
# 75%    121.750000       548.250000   559.250000          3.000000
# max    162.000000       994.000000  1288.000000         13.000000
#
#               Tests  Active Cases
# count    162.000000    162.000000
# mean   33575.043210   8031.216049
# std    16903.979782   5571.706290
# min       75.000000      4.000000
# 25%    22868.500000   2685.250000
# 50%    37132.500000   8338.500000
# 75%    47001.750000  12915.000000
# max    71697.000000  17173.000000

# %%
#Displaying the first 5 rows
dat.head()
# Out:
#             Day  Confirmed Cases  Recovered  Confirmed Deaths  Tests  \
# Date
# 2020-01-29    1                4          0                 0     75
# 2020-02-01    2                1          0                 0    183
# 2020-02-08    3                2          0                 0    574
# 2020-02-09    4                0          1                 0   1360
# 2020-02-10    5                1          0                 0    437
#
#             Active Cases
# Date
# 2020-01-29             4
# 2020-02-01             5
# 2020-02-08             7
# 2020-02-09             6
# 2020-02-10             7

# %%
#Displaying the last 5 rows of the data
dat.tail()
# Out:
#             Day  Confirmed Cases  Recovered  Confirmed Deaths  Tests  \
# Date
# 2020-08-04  158              189        227                 0  29398
# 2020-08-05  159              254        295                 2  43369
# 2020-08-06  160              239        354                 1  50729
# 2020-08-07  161              216        276                 2  61978
# 2020-08-08  162              239        230                 0  63792
#
#             Active Cases
# Date
# 2020-08-04          5911
# 2020-08-05          5868
# 2020-08-06          5752
# 2020-08-07          5690
# 2020-08-08          5699

# %%
#if you want to display any given number of rows from top
dat.head(13)
# Out:
#             Day  Confirmed Cases  Recovered  Confirmed Deaths  Tests  \
# Date
# 2020-01-29    1                4          0                 0     75
# 2020-02-01    2                1          0                 0    183
# 2020-02-08    3                2          0                 0    574
# 2020-02-09    4                0          1                 0   1360
# 2020-02-10    5                1          0                 0    437
# 2020-02-14    6                0          2                 0    306
# 2020-02-16    7                1          0                 0   2107
# 2020-02-18    8                0          0                 0   1651
# 2020-02-21    9                2          0                 0   2201
# 2020-02-22   10                2          0                 0   4096
# 2020-02-27   11                6          2                 0   1325
# 2020-02-28   12                2          0                 0   8606
# ...

# %%
#if you want to display any given number of rows from bottom
covidata.tail(20)    #last 20 rows
# Out:
#             Day  Confirmed Cases  Recovered  Confirmed Deaths  Tests  \
# Date
# 2020-07-20  143              271        352                 1  27224
# 2020-07-21  144              305        343                 1  40050
# 2020-07-22  145              236        390                 1  47014
# 2020-07-23  146              254        494                 0  54096
# 2020-07-24  147              261        387                 1  46965
# 2020-07-25  148              313        393                 0  52627
# 2020-07-26  149              351        554                 1  51162
# 2020-07-27  150              264        328                 1  47229
# 2020-07-28  151              369        395                 2  43622
# 2020-07-29  152              375        297                 0  47483
# 2020-07-30  153              302        424                 2  55257
# 2020-07-31  154              283        283                 2  54727
# ...

# %%
#lets access some parts of our data say by columns
covidata.Day
# Out:
# Date
# 2020-01-29      1
# 2020-02-01      2
# 2020-02-08      3
# 2020-02-09      4
# 2020-02-10      5
#              ...
# 2020-08-04    158
# 2020-08-05    159
# 2020-08-06    160
# 2020-08-07    161
# 2020-08-08    162
# Name: Day, Length: 162, dtype: int64

# %%
covidata.Recovered
# Out:
# Date
# 2020-01-29      0
# 2020-02-01      0
# 2020-02-08      0
# 2020-02-09      1
# 2020-02-10      0
#              ...
# 2020-08-04    227
# 2020-08-05    295
# 2020-08-06    354
# 2020-08-07    276
# 2020-08-08    230
# Name: Recovered, Length: 162, dtype: int64

# %%
covidata.Tests
# Out:
# Date
# 2020-01-29       75
# 2020-02-01      183
# 2020-02-08      574
# 2020-02-09     1360
# 2020-02-10      437
#               ...
# 2020-08-04    29398
# 2020-08-05    43369
# 2020-08-06    50729
# 2020-08-07    61978
# 2020-08-08    63792
# Name: Tests, Length: 162, dtype: int64

# %%
#another way to do that is below
dat["Tests"]
# Out:
# Date
# 2020-01-29       75
# 2020-02-01      183
# 2020-02-08      574
# 2020-02-09     1360
# 2020-02-10      437
#               ...
# 2020-08-04    29398
# 2020-08-05    43369
# 2020-08-06    50729
# 2020-08-07    61978
# 2020-08-08    63792
# Name: Tests, Length: 162, dtype: int64

# %%
dat.iloc[:]        #like all rows and columns
# Out:
#             Day  Confirmed Cases  Recovered  Confirmed Deaths  Tests  \
# Date
# 2020-01-29    1                4          0                 0     75
# 2020-02-01    2                1          0                 0    183
# 2020-02-08    3                2          0                 0    574
# 2020-02-09    4                0          1                 0   1360
# 2020-02-10    5                1          0                 0    437
# ...         ...              ...        ...               ...    ...
# 2020-08-04  158              189        227                 0  29398
# 2020-08-05  159              254        295                 2  43369
# 2020-08-06  160              239        354                 1  50729
# 2020-08-07  161              216        276                 2  61978
# 2020-08-08  162              239        230                 0  63792
#
#             Active Cases
# Date
# 2020-01-29             4
# 2020-02-01             5
# 2020-02-08             7
# ...

# %%
dat.iloc[0:11,2:8]
# Out:
#             Recovered  Confirmed Deaths  Tests  Active Cases
# Date
# 2020-01-29          0                 0     75             4
# 2020-02-01          0                 0    183             5
# 2020-02-08          0                 0    574             7
# 2020-02-09          1                 0   1360             6
# 2020-02-10          0                 0    437             7
# 2020-02-14          2                 0    306             5
# 2020-02-16          0                 0   2107             6
# 2020-02-18          0                 0   1651             6
# 2020-02-21          0                 0   2201             8
# 2020-02-22          0                 0   4096            10
# 2020-02-27          2                 0   1325            14

# %%
dat
# Out:
#             Day  Confirmed Cases  Recovered  Confirmed Deaths  Tests  \
# Date
# 2020-01-29    1                4          0                 0     75
# 2020-02-01    2                1          0                 0    183
# 2020-02-08    3                2          0                 0    574
# 2020-02-09    4                0          1                 0   1360
# 2020-02-10    5                1          0                 0    437
# ...         ...              ...        ...               ...    ...
# 2020-08-04  158              189        227                 0  29398
# 2020-08-05  159              254        295                 2  43369
# 2020-08-06  160              239        354                 1  50729
# 2020-08-07  161              216        276                 2  61978
# 2020-08-08  162              239        230                 0  63792
#
#             Active Cases
# Date
# 2020-01-29             4
# 2020-02-01             5
# 2020-02-08             7
# ...

# %%
dat.shape
# Out:
# (162, 6)

# %%
dat.size   #162*7
# Out:
# 972

# %%
covidata
# Out:
#             Day  Confirmed Cases  Recovered  Confirmed Deaths  Tests  \
# Date
# 2020-01-29    1                4          0                 0     75
# 2020-02-01    2                1          0                 0    183
# 2020-02-08    3                2          0                 0    574
# 2020-02-09    4                0          1                 0   1360
# 2020-02-10    5                1          0                 0    437
# ...         ...              ...        ...               ...    ...
# 2020-08-04  158              189        227                 0  29398
# 2020-08-05  159              254        295                 2  43369
# 2020-08-06  160              239        354                 1  50729
# 2020-08-07  161              216        276                 2  61978
# 2020-08-08  162              239        230                 0  63792
#
#             Active Cases
# Date
# 2020-01-29             4
# 2020-02-01             5
# 2020-02-08             7
# ...

# %%
plt.figure(figsize=(10,6))
plt.grid()
plt.title("UAE COVID-19 UPDATES")
plt.xlabel("Dates")
plt.ylabel("No. of Cases")
sns.lineplot(data=covidata)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure()
plt.grid()
plt.title("COVID-19 CONFIRMED CASES")
plt.xlabel("Dates")
plt.ylabel("No. of Cases")
sns.lineplot(data=covidata["Confirmed Cases"])
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.grid()
plt.title("COVID-19 RECOVERED CASES")
plt.xlabel("Dates")
plt.ylabel("No. of Cases")
sns.lineplot(data=covidata["Recovered"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.grid()
plt.title("COVID-19 CONFIRMED DEATHS CASES")
plt.xlabel("Dates")
plt.ylabel("No. of Cases")
sns.lineplot(data=covidata["Confirmed Deaths"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.grid()
plt.title("UAE COVID-19 TESTS")
plt.xlabel("Dates")
plt.ylabel("No. of Cases")
sns.lineplot(data=covidata["Tests"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.grid()
plt.title("COVID-19 ACTIVE CASES")
plt.xlabel("Dates")
plt.ylabel("No. of Cases")
sns.lineplot(data=covidata["Active Cases"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
sns.barplot(x=covidata["Day"],y=covidata["Active Cases"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
datap =covidata.iloc[0:30,3:5]

# %%
datap
# Out:
#             Confirmed Deaths  Tests
# Date
# 2020-01-29                 0     75
# 2020-02-01                 0    183
# 2020-02-08                 0    574
# 2020-02-09                 0   1360
# 2020-02-10                 0    437
# 2020-02-14                 0    306
# 2020-02-16                 0   2107
# 2020-02-18                 0   1651
# 2020-02-21                 0   2201
# 2020-02-22                 0   4096
# 2020-02-27                 0   1325
# 2020-02-28                 0   8606
# 2020-03-03                 0   2113
# 2020-03-04                 0  12724
# 2020-03-06                 0  10753
# 2020-03-07                 0   4480
# 2020-03-09                 0   6949
# 2020-03-10                 0   3618
# 2020-03-12                 0   9973
# 2020-03-14                 0  10040
# 2020-03-15                 0   6616
# 2020-03-17                 0  10525
# 2020-03-19                 0  13857
# 2020-03-21                 2  12706
# 2020-03-23                 0  16748
# ...

# %%
plt.figure()
plt.title("Heatmap for covid-19 data")
sns.heatmap(data=datap,annot=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
